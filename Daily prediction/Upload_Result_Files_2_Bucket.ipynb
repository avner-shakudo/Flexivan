# %%
import boto3
import os
import pandas as pd

# %%
# CREDENTIALS

# Bucket name = flexivan-shakudo
# AWS_ACCESS_KEY_ID = AKIA22DCUZYCIUOZBKNE
# AWS_SECRET_ACCESS_KEY = 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
# AWS_REGION:-us-west-1

# %%
def list_csv_files(df, path_column):
    """
    Filters and displays all CSV filenames from a DataFrame column
    containing full file paths.

    Parameters
    ----------
    df : pandas.DataFrame
        The DataFrame containing file paths.
    path_column : str
        The name of the column that holds full file paths.

    Returns
    -------
    pandas.DataFrame
        A filtered DataFrame containing only CSV files,
        with an added 'filename' column.
    """
    # Filter rows that end with .csv (case-insensitive)
    csv_df = df[df[path_column].str.lower().str.endswith('.csv')].copy()

    # Extract just the filename from the full path
    csv_df['filename'] = csv_df[path_column].apply(os.path.basename)

    # Display the results
    print(f"📄 CSV files found: {len(csv_df)}")
    print(csv_df['filename'].to_string(index=False))

    return csv_df

# %%
Folder = '/Users/avner/flexivan/Daily prediction/DATA'
bucket = 'flexivan-shakudo'

# %%
# Get a DF with filenames to upload

filenames = os.listdir(Folder)
filenames = [f for f in filenames if os.path.isfile(os.path.join(Folder, f))]
df = pd.DataFrame({'filename': filenames})
FILENAMES = list_csv_files(df, Folder)
FILENAMES
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/flexivan/Daily prediction/venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '/Users/avner/flexivan/Daily prediction/DATA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 6
#       4 filenames = [f for f in filenames if os.path.isfile(os.path.join(Folder, f))]
#       5 df = pd.DataFrame({'filename': filenames})
# ----> 6 FILENAMES = list_csv_files(df, Folder)
#       7 FILENAMES
#
# Cell In[5], line 20, in list_csv_files(df, path_column)
#       2 """
#       3 Filters and displays all CSV filenames from a DataFrame column
#       4 containing full file paths.
#    (...)     17     with an added 'filename' column.
#      18 """
#      19 # Filter rows that end with .csv (case-insensitive)
# ---> 20 csv_df = df[df[path_column].str.lower().str.endswith('.csv')].copy()
#      22 # Extract just the filename from the full path
#      23 csv_df['filename'] = csv_df[path_column].apply(os.path.basename)
#
# File ~/flexivan/Daily prediction/venv/lib/python3.14/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/flexivan/Daily prediction/venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '/Users/avner/flexivan/Daily prediction/DATA'
